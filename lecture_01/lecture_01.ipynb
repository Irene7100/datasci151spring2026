# %% [markdown]
# These are where lecture notes will be written, describing what's happening in the code cells

# %% [markdown]
# There are different ways of changing fonts...
#
#
# <font size = "4">
#
# Font size 4
#
# other text
# other text
#
# <font size = "10">
# Font size 10
#
# other text
# <font size = "1">
#
# small text

# %% [markdown]
# # Biggest text
#
# ### slightly smaller
#
#
# ###### smallest

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
#  ## Notes on things I didn't understand

# %%
print("Goodbye")
# Out:
# Goodbye
